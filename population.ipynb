# %%
import pandas as pd

# %%
pop2010_20 = pd.read_csv('datasets/co-est2010-2020_alldata.csv', encoding='latin1')
pop2020_23 = pd.read_csv('datasets/co-est2020-2023_alldata.csv', encoding='latin1')

# %%
pop2010_20.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#   CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RNETMIG2011  \
# 0       4779736            4780118          4785514  ...     0.680010
# 1         54571              54582            54761  ...     6.236931
# 2        182265             182263           183121  ...    16.705437
# 3         27457              27454            27325  ...     0.329254
# 4         22915              22904            22858  ...    -4.912927
#
#    RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015  RNETMIG2016  \
# ...

# %%
pop2020_23.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    ESTIMATESBASE2020  POPESTIMATE2020  POPESTIMATE2021  ...  RNATURALCHG2023  \
# 0            5024294          5031864          5050380  ...        -0.306805
# 1              58809            58915            59203  ...         1.549122
# 2             231768           233227           239439  ...        -0.435967
# 3              25229            24969            24533  ...        -3.368165
# 4              22301            22188            22359  ...        -2.280294
#
#    RINTERNATIONALMIG2021  RINTERNATIONALMIG2022  RINTERNATIONALMIG2023  \
# ...

# %%
pop2010_20.value_counts()
# Out:
# SUMLEV  REGION  DIVISION  STATE  COUNTY  STNAME       CTYNAME            CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015  POPESTIMATE2016  POPESTIMATE2017  POPESTIMATE2018  POPESTIMATE2019  POPESTIMATE2020  NPOPCHG_2010  NPOPCHG_2011  NPOPCHG_2012  NPOPCHG_2013  NPOPCHG_2014  NPOPCHG_2015  NPOPCHG_2016  NPOPCHG_2017  NPOPCHG_2018  NPOPCHG_2019  NPOPCHG_2020  BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  BIRTHS2014  BIRTHS2015  BIRTHS2016  BIRTHS2017  BIRTHS2018  BIRTHS2019  BIRTHS2020  DEATHS2010  DEATHS2011  DEATHS2012  DEATHS2013  DEATHS2014  DEATHS2015  DEATHS2016  DEATHS2017  DEATHS2018  DEATHS2019  DEATHS2020  NATURALINC2010  NATURALINC2011  NATURALINC2012  NATURALINC2013  NATURALINC2014  NATURALINC2015  NATURALINC2016  NATURALINC2017  NATURALINC2018  NATURALINC2019  NATURALINC2020  INTERNATIONALMIG2010  INTERNATIONALMIG2011  INTERNATIONALMIG2012  INTERNATIONALMIG2013  INTERNATIONALMIG2014  
# ...

# %%
columns = ['STNAME', 'COUNTY', 'CTYNAME']
columns.extend(['POPESTIMATE20' + f'{i:02d}' for i in range(10,20)])

# %%
popComplete = pop2010_20[columns]
popComplete
# Out:
#        STNAME  COUNTY            CTYNAME  POPESTIMATE2010  POPESTIMATE2011  \
# 0     Alabama       0            Alabama          4785514          4799642
# 1     Alabama       1     Autauga County            54761            55229
# 2     Alabama       3     Baldwin County           183121           186579
# 3     Alabama       5     Barbour County            27325            27344
# 4     Alabama       7        Bibb County            22858            22736
# ...       ...     ...                ...              ...              ...
# 3189  Wyoming      37  Sweetwater County            43580            44000
# 3190  Wyoming      39       Teton County            21298            21422
# 3191  Wyoming      41       Uinta County            21090            20901
# 3192  Wyoming      43    Washakie County             8531             8451
# 3193  Wyoming      45      Weston County             7198             7142
#
# ...
